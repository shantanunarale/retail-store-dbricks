-- %%
CREATE STREAMING TABLE IF NOT EXISTS products_raw;

-- %%
CREATE FLOW products_raw AS
INSERT INTO products_raw BY NAME
SELECT * 
FROM STREAM read_files(
  '/Volumes/${catalog}/landing/retail_store/product/',
  format => 'csv',
  header => TRUE
);
