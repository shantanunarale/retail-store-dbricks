# %%
# %sql
USE CATALOG IDENTIFIER(:catalog);
USE SCHEMA landing;

# %%
# %sql
CREATE EXTERNAL VOLUME IF NOT EXISTS retail_store
LOCATION 'abfss://retail-store@stexdevcentralindia001.dfs.core.windows.net/'
COMMENT 'landing volume';
