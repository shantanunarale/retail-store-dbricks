# %%
import sys, os
cwd = os.getcwd()
sys.path.append(os.path.abspath(os.path.join(cwd, "../../../python")))
import utility as u

# %%
from pyspark.sql.functions import col, lit, expr, current_timestamp

# %%
catalog = dbutils.widgets.get("catalog")

# %%
max_batch_id = u.getMaxBatchId(spark, f"{catalog}.bronze.employees").collect()[0].BatchId

# %%
spark.read \
    .table("employee_store_sql.dbo.employees") \
        .withColumn("BatchId", lit(max_batch_id) + 1) \
            .withColumn("LoadDate", current_timestamp()) \
                .writeTo(f"{catalog}.bronze.employees") \
                    .append()
