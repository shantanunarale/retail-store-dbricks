# %%
from pyspark.sql.functions import col, lit, expr, max

# %%
catalog = dbutils.widgets.get("catalog")

# %%
df = spark.sql(f"""
               SELECT *
               FROM {catalog}.bronze.employees
               WHERE BatchId = (SELECT max(BatchId) FROM {catalog}.bronze.employees)
               """)

# %%
df.write \
    .insertInto(
        f"{catalog}.silver.employees",
        overwrite=True
    )
