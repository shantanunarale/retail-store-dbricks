# %%
# %sql
USE CATALOG IDENTIFIER(:catalog);
COPY INTO bronze.product
FROM '/Volumes/${catalog}/landing/retail_store/product/'
FILEFORMAT = csv
FORMAT_OPTIONS ('header' = 'true', 'pathGlobFilter' = '*.csv', 'inferSchema' = 'true')
